# %% [markdown]
# <a href="https://colab.research.google.com/github/abxda/Colmex2023/blob/main/Taller_Colmex_D%C3%ADa_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y python3-dev python3-numpy libtiff-dev libjpeg-dev zlib1g-dev libpng-dev libsqlite3-dev libpq-dev libxerces-c-dev libgeos-dev libproj-dev libopenjp2-7-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu10).
# libjpeg-dev set to manually installed.
# libopenjp2-7-dev is already the newest version (2.4.0-6).
# libopenjp2-7-dev set to manually installed.
# libpng-dev is already the newest version (1.6.37-3build5).
# libgeos-dev is already the newest version (3.10.2-1).
# libgeos-dev set to manually installed.
# libproj-dev is already the newest version (8.2.1-1).
# libproj-dev set to manually installed.
# libxerces-c-dev is already the newest version (3.2.3+debian-3build1).
# libxerces-c-dev set to manually installed.
# libpq-dev is already the newest version (14.9-0ubuntu0.22.04.1).
# libpq-dev set to manually installed.
# libsqlite3-dev is already the newest version (3.37.2-2ubuntu0.1).
# libsqlite3-dev set to manually installed.
# libtiff-dev is already the newest version (4.3.0-6ubuntu0.5).
# ...

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_miniconda()
#Más información en: https://pypi.org/project/condacolab/
# Out:
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py310_23.3.1-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda update -n base conda -y
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       h06a4308_0         123 KB
#     certifi-2023.7.22          |  py310h06a4308_0         153 KB
#     conda-23.7.4               |  py310h06a4308_0         1.0 MB
#     conda-package-handling-2.2.0|  py310h06a4308_0         268 KB
#     conda-package-streaming-0.9.0|  py310h06a4308_0          27 KB
#     cryptography-41.0.3        |  py310hdda0065_0         2.0 MB
#     libffi-3.4.4               |       h6a678d5_0         142 KB
#     openssl-3.0.11             |       h7f8727e_2         5.2 MB
#     packaging-23.1             |  py310h06a4308_0          78 KB
# ...

# %%
# !apt-get install -y gdal-bin python3-gdal libgdal-dev
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgdal-dev is already the newest version (3.4.3+dfsg-1~jammy0).
# Suggested packages:
#   libgdal-grass
# The following NEW packages will be installed:
#   gdal-bin python3-gdal
# 0 upgraded, 2 newly installed, 0 to remove and 18 not upgraded.
# Need to get 1,501 kB of archives.
# After this operation, 5,958 kB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-gdal amd64 3.4.3+dfsg-1~jammy0 [967 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 gdal-bin amd64 3.4.3+dfsg-1~jammy0 [534 kB]
# Fetched 1,501 kB in 5s (321 kB/s)
# Selecting previously unselected package python3-gdal.
# (Reading database ... 121679 files and directories currently installed.)
# ...

# %%
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test -y
# !sudo apt-get update
# !sudo apt-get upgrade libstdc++6
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...

# %%
import os
os.environ['LD_LIBRARY_PATH'] = "/usr/lib/x86_64-linux-gnu"

# %%
# !conda install -c conda-forge proj4  -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - proj4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       hbcca054_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     conda-23.7.4               |  py310hff52083_0        1006 KB  conda-forge
#     proj4-6.1.1                |       hc80f0dc_1         9.8 MB  conda-forge
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   proj4              conda-forge/linux-64::proj4-6.1.1-hc80f0dc_1
#   python_abi         conda-forge/linux-64::python_abi-3.10-2_cp310
#
# ...

# %%
import pyproj

proj_dir = pyproj.datadir.get_data_dir()
os.environ['PROJ_LIB'] = proj_dir
print(proj_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/proj_dir/share/proj

# %%
# !conda install -c conda-forge gdal -y
# Out:
# done
# unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# /

# %%
# !conda install -c conda-forge rsgislib=5.0.14 -y
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.4
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - gdal=3.7.2
#     - rsgislib=5.0.14
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blosc-1.21.5               |       h0f2a231_0          48 KB  conda-forge
#     boost-cpp-1.78.0           |       h2c5509c_4        15.2 MB  conda-forge
# ...

# %%
 # !ls /usr/lib/python3/dist-packages/osgeo

# %%
#!rm -rf /usr/lib/python3/dist-packages/osgeo

# %%
#Reiniciar el kernel
#Menú Entorno de Ejecución -> Reiniciar Entorno de Ejecución
#

# %%
# !gdalinfo --version
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# GDAL 3.7.2, released 2023/09/05

# %%
# !conda list rsgislib
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# rsgislib                  5.0.14          py310h858af48_2    conda-forge

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import rsgislib.vectorutils.createrasters
from rsgislib import TYPE_32INT

# %%
# !ls -alht /content/drive/MyDrive/'Curso COLMEX 2023'
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# total 11G
# -rw------- 1 root root 2.4G Sep 22 22:16 GM_AGS_2020_COLMEX_02.tif
# -rw------- 1 root root 1.5G Sep 22 22:06 GM_AGS_2020_COLMEX_03.tif
# -rw------- 1 root root 124M Sep 22 18:40 grid_100m_aea.dbf
# -rw------- 1 root root 144M Sep 22 18:40 grid_100m_aea.shp
# -rw------- 1 root root 8.5M Sep 22 18:40 grid_100m_aea.shx
# -rw------- 1 root root  447 Sep 22 18:40 grid_100m_aea.prj
# -rw------- 1 root root 2.1G Sep 20 19:36 GM_AGS_2020_COLMEX_01.tif
# -rw------- 1 root root 2.1G Sep 18 21:54 GM_AGS_2020_COLMEX.tif
# -rw------- 1 root root 2.5G Jul 23  2022 GM_AGS_2020.tif

# %%
inputVector = "/content/drive/MyDrive/Curso COLMEX 2023/grid_100m_aea.shp"
inputVectorLyr = 'grid_100m_aea'
inputImage = "/content/drive/MyDrive/Curso COLMEX 2023/GM_AGS_2020_COLMEX.tif"
outputImage = "/content/drive/MyDrive/Curso COLMEX 2023/grid_100m.kea"
rsgislib.vectorutils.createrasters.rasterise_vec_lyr(
                              vec_file = inputVector,
                              vec_lyr = inputVectorLyr,
                              input_img = inputImage,
                              output_img = outputImage,
                              datatype = TYPE_32INT,
                              gdalformat = 'KEA',
                              att_column ='id')
